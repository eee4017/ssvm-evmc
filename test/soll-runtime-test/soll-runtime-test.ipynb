# %%
import ctypes
from binascii import unhexlify
from evmc import *
import os, signal
from Crypto.Util.number import *

handle = ctypes.cdll.LoadLibrary('./libsoll_runtime_test.so')

def int_to_address(x):
    return ctypes.c_buffer(long_to_bytes(x).rjust(20, b'\x00'), size=20)

def int_to_bytes32(x):
    return ctypes.c_buffer(long_to_bytes(x).rjust(32, b'\x00'), size=32)

def print_red(x):
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    print(FAIL + x + ENDC)

def print_green(x):
    GREEN = '\033[92m'
    ENDC = '\033[0m'
    print(GREEN + x + ENDC)

def evmc_vm_execute(calldata:bytes, sender:int, destination:int, wasm:bytes):
    _evmc_vm_execute = handle.evmc_vm_execute
    
    sender = int_to_address(sender)
    destination = int_to_address(destination)
    
    result = struct_evmc_result()
    _evmc_vm_execute( 
                    ctypes.cast(calldata, ctypes.c_char_p), 
                    len(calldata), 
                    ctypes.pointer(sender),
                    ctypes.pointer(destination),
                    ctypes.cast(wasm, ctypes.c_char_p), 
                    len(wasm), 
                    ctypes.pointer(result))
    
    return evmc_status_code__enumvalues[result.status_code], result

def evmc_vm_deploy(deploy_wasm:bytes):
    _evmc_vm_deploy = handle.evmc_vm_deploy

    result = struct_evmc_result()
    _evmc_vm_deploy(ctypes.cast(deploy_wasm, ctypes.c_char_p), 
                    len(deploy_wasm), 
                    ctypes.pointer(result))
    
    return evmc_status_code__enumvalues[result.status_code], result

def evmc_get_storage(address:int, key:int):
    _evmc_get_storage = handle.evmc_get_storage
    
    address = int_to_address(address)
    key = int_to_bytes32(key)
    result = int_to_bytes32(0)

    _evmc_get_storage(
                    ctypes.pointer(address), 
                    ctypes.pointer(key), 
                    ctypes.pointer(result))
    
    return bytes(result.raw)

# %%
def testing(testbase):
    basic_sstore = open(f'{testbase}.wasm', 'rb').read()

    calldata = unhexlify("")
    sender = 0x0
    destination = 0x7ffffffff
    result_str, result = evmc_vm_execute(calldata, 0, destination, basic_sstore)
    if result_str == 'EVMC_SUCCESS':
        print_green(f"evmc vm execute result: {result_str}")
    else:
        print_red(f"evmc vm execute result: {result_str}")
        return -1, False
        

    storage_dump = dict()
    with open(f'{testbase}.yul', 'r') as f:
        storage_dump_flag = False
        for line in f:
            if storage_dump_flag:
                _, key, value = line.split()
                key, value = int(key[:-1], 16), int(value, 16)
                storage_dump[key] = value
            if line.find('Storage dump:') != -1:
                storage_dump_flag = True

    num_testcase = len(storage_dump)
#     print(f"checking evmc storage with expected {num_testcase} testcases:", storage_dump)
    
    result = True
    for i, p in enumerate(storage_dump.items()):
        k, v = p
        execute_result = bytes_to_long(evmc_get_storage(destination, k))
        result = result and (v == execute_result) 
        if (v == execute_result):
            print_green(f"testcase-{i}: PASS")
        else:
            print_red(f"testcase-{i}: FAIL")
            
    return num_testcase, result

# %%
num_testcase, result = testing('./libyul/ewasmTranslationTests/bitwise_and')
# Out:
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS

# %%
import glob

# %%
files = []
files.extend(glob.glob('./libyul/*/*.yul'))
files.extend(glob.glob('./yul/*/*.yul'))
files.extend(glob.glob('./yul/*.yul'))

# %%
num_test = 0
num_run = 0
num_has_testcase = 0
num_pass = 0

for file in files:
    print("========================================")
    base = file[:-4]
    print(base)    
    if os.path.isfile(base + '.yul') and os.path.isfile(base + '.wasm'):
        num_testcase, result = testing(base)
        num_test += 1
        if num_testcase > 0:
            num_run += 1
            num_has_testcase += 1
            
            if (result):
                num_pass += 1
                print_green(f"{base}: PASS")
            else:
                print_red(f"{base}: FAIL")
        elif num_testcase == 0:
            num_run += 1
            print(f"{base}: HAS NO TESTCASE") 
        else:
            print_red(f"{base}: FAIL")
# Out:
# ========================================
# ./libyul/functionSideEffects/mload_in_function
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/mload_in_function: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/multi_calls
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/multi_calls: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/structures
# evmc vm execute result: EVMC_FAILURE
# ./libyul/functionSideEffects/structures: FAIL
# ========================================
# ./libyul/functionSideEffects/empty_with_sstore
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/empty_with_sstore: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/simple_functions
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/simple_functions: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/empty
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/empty: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/with_loop
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/with_loop: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/cyclic_graph
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/cyclic_graph: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/doubly_recursive_function
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/doubly_recursive_function: HAS NO TESTCASE
# ========================================
# ./libyul/functionSideEffects/recursive_function
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/functionSideEffects/recursive_function: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/datasize_code
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/datasize_code: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/namedObjectCode
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/namedObjectCode: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/datasize_self
# ========================================
# ./libyul/objectCompiler/dataoffset_data
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/dataoffset_data: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/simple
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/simple: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/dataoffset_code
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/dataoffset_code: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/subSubObject
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/subSubObject: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/subObject
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/subObject: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/smoke
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/smoke: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/nested_optimizer
# evmc vm execute result: EVMC_FAILURE
# ./libyul/objectCompiler/nested_optimizer: FAIL
# ========================================
# ./libyul/objectCompiler/datasize_data
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/datasize_data: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/function_series
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/function_series: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/data
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/data: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/simple_optimizer
# evmc vm execute result: EVMC_FAILURE
# ./libyul/objectCompiler/simple_optimizer: FAIL
# ========================================
# ./libyul/objectCompiler/namedObject
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/objectCompiler/namedObject: HAS NO TESTCASE
# ========================================
# ./libyul/objectCompiler/dataoffset_self
# ========================================
# ./libyul/objectCompiler/datacopy
# ========================================
# ./libyul/yulInterpreterTests/datasize
# ========================================
# ./libyul/yulInterpreterTests/leave_for_init
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/yulInterpreterTests/leave_for_init: PASS
# ========================================
# ./libyul/yulInterpreterTests/leave
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/yulInterpreterTests/leave: PASS
# ========================================
# ./libyul/yulInterpreterTests/exp
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/exp: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/dataoffset
# ========================================
# ./libyul/yulInterpreterTests/function_calls
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/yulInterpreterTests/function_calls: PASS
# ========================================
# ./libyul/yulInterpreterTests/recursion
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/yulInterpreterTests/recursion: PASS
# ========================================
# ./libyul/yulInterpreterTests/switch_statement
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/switch_statement: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/ambiguous_vars
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/ambiguous_vars: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/access_large_memory_offsets
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# ./libyul/yulInterpreterTests/access_large_memory_offsets: PASS
# ========================================
# ./libyul/yulInterpreterTests/shadowed_symbol
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/shadowed_symbol: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/simple_mstore
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/simple_mstore: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/recursive_function_for_loop
# evmc vm execute result: EVMC_FAILURE
# ./libyul/yulInterpreterTests/recursive_function_for_loop: FAIL
# ========================================
# ./libyul/yulInterpreterTests/loop
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/loop: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/smoke
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/yulInterpreterTests/smoke: HAS NO TESTCASE
# ========================================
# ./libyul/yulInterpreterTests/function_scopes
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# ./libyul/yulInterpreterTests/function_scopes: PASS
# ========================================
# ./libyul/yulInterpreterTests/external_call
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/yulInterpreterTests/external_call: FAIL
# ========================================
# ./libyul/yulInterpreterTests/datacopy
# ========================================
# ./libyul/ewasmTranslationTests/extcodecopy
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/extcodecopy: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/mstore_mload
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/ewasmTranslationTests/mstore_mload: PASS
# ========================================
# ./libyul/ewasmTranslationTests/bitwise_or
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# testcase-6: PASS
# ./libyul/ewasmTranslationTests/bitwise_or: PASS
# ========================================
# ./libyul/ewasmTranslationTests/coinbase
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/coinbase: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/balance
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/balance: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/datasize
# ========================================
# ./libyul/ewasmTranslationTests/invalid
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/invalid: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/bitwise_not
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# testcase-6: PASS
# testcase-7: PASS
# ./libyul/ewasmTranslationTests/bitwise_not: PASS
# ========================================
# ./libyul/ewasmTranslationTests/keccak256
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/keccak256: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/number
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/number: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/smoke_delegatecall
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_delegatecall: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/codecopy
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/codecopy: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/revert
# evmc vm execute result: EVMC_REVERT
# ./libyul/ewasmTranslationTests/revert: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/timestamp
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/timestamp: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/log0
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/log0: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/bitwise_and
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# ./libyul/ewasmTranslationTests/bitwise_and: PASS
# ========================================
# ./libyul/ewasmTranslationTests/dataoffset
# ========================================
# ./libyul/ewasmTranslationTests/extcodesize
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/extcodesize: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/gas
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/gas: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/selfbalance
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/selfbalance: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/difficulty
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/difficulty: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/smoke_callcode
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_callcode: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/iszero
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# ./libyul/ewasmTranslationTests/iszero: PASS
# ========================================
# ./libyul/ewasmTranslationTests/comparison_eq
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# ./libyul/ewasmTranslationTests/comparison_eq: PASS
# ========================================
# ./libyul/ewasmTranslationTests/gaslimit
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/gaslimit: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/mstore8
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/mstore8: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/smoke_create
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_create: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/gasprice
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/gasprice: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/log3
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/log3: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/returndatasize
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/returndatasize: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/msize
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/msize: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/simple_mstore
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/simple_mstore: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/returndatacopy
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/returndatacopy: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/address
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/address: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/comparison_sgt
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: FAIL
# testcase-5: PASS
# testcase-6: FAIL
# testcase-7: FAIL
# testcase-8: PASS
# ./libyul/ewasmTranslationTests/comparison_sgt: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/comparison_lt
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# ./libyul/ewasmTranslationTests/comparison_lt: PASS
# ========================================
# ./libyul/ewasmTranslationTests/comparison_gt
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# ./libyul/ewasmTranslationTests/comparison_gt: PASS
# ========================================
# ./libyul/ewasmTranslationTests/calldatasize
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/calldatasize: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/bitwise_xor
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: PASS
# testcase-5: PASS
# testcase-6: PASS
# testcase-7: PASS
# ./libyul/ewasmTranslationTests/bitwise_xor: PASS
# ========================================
# ./libyul/ewasmTranslationTests/callvalue
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/callvalue: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/caller
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/caller: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/log2
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/log2: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/shifts
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# ./libyul/ewasmTranslationTests/shifts: PASS
# ========================================
# ./libyul/ewasmTranslationTests/smoke
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/log1
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/log1: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/selfdestruct
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/selfdestruct: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/return
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/return: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/calldatacopy
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/calldatacopy: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/codesize
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/codesize: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/log4
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/log4: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/blockhash
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/blockhash: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/calldataload
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/calldataload: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/extcodehash
# evmc vm execute result: EVMC_FAILURE
# ./libyul/ewasmTranslationTests/extcodehash: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/smoke_call
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_call: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/origin
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: FAIL
# ./libyul/ewasmTranslationTests/origin: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/chainid
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/chainid: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/smoke_create2
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_create2: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/simple_sload
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# ./libyul/ewasmTranslationTests/simple_sload: PASS
# ========================================
# ./libyul/ewasmTranslationTests/simple_sstore
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# ./libyul/ewasmTranslationTests/simple_sstore: PASS
# ========================================
# ./libyul/ewasmTranslationTests/comparison_slt
# evmc vm execute result: EVMC_SUCCESS
# testcase-0: PASS
# testcase-1: PASS
# testcase-2: PASS
# testcase-3: PASS
# testcase-4: FAIL
# testcase-5: PASS
# testcase-6: FAIL
# testcase-7: FAIL
# testcase-8: PASS
# ./libyul/ewasmTranslationTests/comparison_slt: FAIL
# ========================================
# ./libyul/ewasmTranslationTests/smoke_staticcall
# evmc vm execute result: EVMC_SUCCESS
# ./libyul/ewasmTranslationTests/smoke_staticcall: HAS NO TESTCASE
# ========================================
# ./libyul/ewasmTranslationTests/datacopy
# ========================================
# ./yul/fe-yul/return_division_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_division_u256: FAIL
# ========================================
# ./yul/fe-yul/return_bitwiseand_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_bitwiseand_u256: FAIL
# ========================================
# ./yul/fe-yul/return_addition_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_addition_u256: FAIL
# ========================================
# ./yul/fe-yul/return_array
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_array: FAIL
# ========================================
# ./yul/fe-yul/return_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_u256: FAIL
# ========================================
# ./yul/fe-yul/return_eq_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_eq_u256: FAIL
# ========================================
# ./yul/fe-yul/address_bytes10_map
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/address_bytes10_map: FAIL
# ========================================
# ./yul/fe-yul/return_bitwiseshr_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_bitwiseshr_u256: FAIL
# ========================================
# ./yul/fe-yul/return_subtraction_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_subtraction_u256: FAIL
# ========================================
# ./yul/fe-yul/u256_u256_map
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/u256_u256_map: FAIL
# ========================================
# ./yul/fe-yul/return_lte_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_lte_u256: FAIL
# ========================================
# ./yul/fe-yul/multi_param
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/multi_param: FAIL
# ========================================
# ./yul/fe-yul/return_gt_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_gt_u256: FAIL
# ========================================
# ./yul/fe-yul/return_pow_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_pow_u256: FAIL
# ========================================
# ./yul/fe-yul/guest_book
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/guest_book: FAIL
# ========================================
# ./yul/fe-yul/return_bitwiseor_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_bitwiseor_u256: FAIL
# ========================================
# ./yul/fe-yul/return_gte_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_gte_u256: FAIL
# ========================================
# ./yul/fe-yul/return_mod_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_mod_u256: FAIL
# ========================================
# ./yul/fe-yul/return_identity_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_identity_u256: FAIL
# ========================================
# ./yul/fe-yul/return_sender
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_sender: FAIL
# ========================================
# ./yul/fe-yul/return_bitwiseshl_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_bitwiseshl_u256: FAIL
# ========================================
# ./yul/fe-yul/return_noteq_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_noteq_u256: FAIL
# ========================================
# ./yul/fe-yul/return_bitwisexor_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_bitwisexor_u256: FAIL
# ========================================
# ./yul/fe-yul/return_multiplication_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_multiplication_u256: FAIL
# ========================================
# ./yul/fe-yul/return_lt_u256
# evmc vm execute result: EVMC_FAILURE
# ./yul/fe-yul/return_lt_u256: FAIL
# ========================================
# ./yul/factorial
# evmc vm execute result: EVMC_SUCCESS
# ./yul/factorial: HAS NO TESTCASE
# ========================================
# ./yul/memory
# evmc vm execute result: EVMC_SUCCESS
# ./yul/memory: HAS NO TESTCASE
# ========================================
# ./yul/switch
# evmc vm execute result: EVMC_SUCCESS
# ./yul/switch: HAS NO TESTCASE
# ========================================
# ./yul/fib
# evmc vm execute result: EVMC_SUCCESS
# ./yul/fib: HAS NO TESTCASE
# ========================================
# ./yul/address
# evmc vm execute result: EVMC_SUCCESS
# ./yul/address: HAS NO TESTCASE
# ========================================
# ./yul/tuple
# evmc vm execute result: EVMC_SUCCESS
# ./yul/tuple: HAS NO TESTCASE
# ========================================
# ./yul/alias
# evmc vm execute result: EVMC_SUCCESS
# ./yul/alias: HAS NO TESTCASE
# ========================================
# ./yul/codesize
# evmc vm execute result: EVMC_SUCCESS
# ./yul/codesize: HAS NO TESTCASE
# ========================================
# ./yul/feature
# evmc vm execute result: EVMC_SUCCESS
# ./yul/feature: HAS NO TESTCASE

# %%
print(num_test, num_run, num_has_testcase, num_pass)
print("pass rate (can run):", 100 * num_run / num_test, "%")
print("pass rate (storage correct):", 100 * num_pass / num_has_testcase, "%")
# Out:
# 132 96 33 18
# pass rate (can run): 72.72727272727273 %
# pass rate (storage correct): 54.54545454545455 %

# %%
testing('./libyul/objectCompiler/simple_optimizer')
# Out:
# evmc vm execute result: EVMC_FAILURE
# (-1, False)
